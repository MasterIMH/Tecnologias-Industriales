# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python3 -m pip install influxdb
# Out:
# Requirement already satisfied: influxdb in /usr/local/lib/python3.7/dist-packages (5.3.1)
# Requirement already satisfied: requests>=2.17.0 in /usr/local/lib/python3.7/dist-packages (from influxdb) (2.23.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from influxdb) (1.0.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from influxdb) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from influxdb) (2.8.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from influxdb) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.17.0->influxdb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.17.0->influxdb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.17.0->influxdb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.17.0->influxdb) (2021.10.8)

# %%
from influxdb import InfluxDBClient
import json
import pandas as pd
import time
client = InfluxDBClient(host='casaeibar.ddns.net', port=8086, username='pi', password='raspberry')

# %%
i =0
while True:
  i= i+1
  results = client.query('SELECT * FROM "Datos"' ,database = 'ascensores').get_points()
  df = pd.DataFrame.from_records(results)
  #df.to_csv('/content/drive/MyDrive/Master/Tecnologías Industriales/IMH TRABAJO TECNOLOGIAS INDUSTRIALES/Datos_ascensores.csv',index = None)
  df.to_csv('/content/drive/MyDrive/Master/Tecnologías Industriales/Datos_ascensores.csv',index = None)
  print("Actualizado {0} veces ".format(i))
  
  time.sleep(15)
# Out:
# Actualizado 1 veces
# Actualizado 2 veces
# Actualizado 3 veces
# Actualizado 4 veces
# Actualizado 5 veces
# Actualizado 6 veces
# Actualizado 7 veces
# Actualizado 8 veces
# Actualizado 9 veces
# Actualizado 10 veces
# Actualizado 11 veces
# Actualizado 12 veces
# Actualizado 13 veces
# Actualizado 14 veces
# Actualizado 15 veces
# Actualizado 16 veces
# Actualizado 17 veces
# Actualizado 18 veces
# Actualizado 19 veces
# Actualizado 20 veces
# Actualizado 21 veces
# Actualizado 22 veces
# Actualizado 23 veces
# Actualizado 24 veces
# Actualizado 25 veces
# Actualizado 26 veces
# Actualizado 27 veces
# Actualizado 28 veces
# Actualizado 29 veces
# Actualizado 30 veces
# Actualizado 31 veces
# Actualizado 32 veces
# Actualizado 33 veces
# Actualizado 34 veces
# Actualizado 35 veces

# %%
results = client.query('SELECT * FROM "Datos"' ,database = 'ascensores').get_points()
df = pd.DataFrame.from_records(results)
df.to_csv(index = None)
